# %% [markdown]
# <a href="https://colab.research.google.com/github/Umerranjum/AI/blob/main/spamLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #For numerical operationn
import pandas as pd #To see data
import re #regular expressions
import nltk #for text manipulation
from nltk.corpus import stopwords
nltk.download('stopwords')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df1 = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df1
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df1 = df1.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)

# %%
df1
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# Convert all the text to lower characters
df1 = df1.apply(lambda x: x.astype(str).str.lower())

# %%
#Remove all the special characters & numbers
df1 = df1.replace(r'[^a-zA-Z\s]', '', regex=True)

# %%
#Abbreviations

# %%
stop_words = set(stopwords.words('english'))

# %%
X = df1['v2'] #Assigning the 'v2' column of df1 to the variable X
y = df1['v1'] #Assigning the 'v1' column of df1 to the variable y

# %%
# Vectorize the data in X
vec = CountVectorizer()
vec.fit(X)
vec.vocabulary_
# Out:
# {'go': 2846,
#  'until': 7756,
#  'jurong': 3740,
#  'point': 5490,
#  'crazy': 1557,
#  'available': 489,
#  'only': 5076,
#  'in': 3457,
#  'bugis': 944,
#  'great': 2942,
#  'world': 8254,
#  'la': 3893,
#  'buffet': 942,
#  'cine': 1274,
#  'there': 7329,
#  'got': 2903,
#  'amore': 247,
#  'wat': 8003,
#  'ok': 5036,
#  'lar': 3929,
#  'joking': 3708,
#  'wif': 8144,
#  'oni': 5070,
#  'free': 2635,
#  'entry': 2219,
#  'wkly': 8205,
#  'comp': 1390,
#  'to': 7457,
#  'win': 8159,
#  'fa': 2355,
#  'cup': 1614,
#  'final': 2481,
#  'tkts': 7446,
#  'st': 6840,
#  'may': 4373,
#  'text': 7272,
#  'receive': 5893,
#  'questionstd': 5784,
#  'txt': 7655,
#  'ratetcs': 5837,
#  'apply': 339,
#  'overs': 5178,
#  'dun': 2070,
#  'say': 6242,
#  'so': 6659,
#  'early': 2092,
#  'hor': 3279,
#  'already': 220,
#  'then': 7324,
#  'nah': 4734,
#  'dont': 1979,
#  'think': 7353,
#  'he': 3100,
#  'goes': 2859,
#  'usf': 7806,
#  'lives': 4096,
#  'around': 390,
#  'here': 3155,
#  'though': 7376,
#  'freemsg': 2643,
#  'hey': 3174,
#  'darling': 1677,
#  'its': 3613,
#  'been': 648,
#  'weeks': 8059,
#  'now': 4931,
#  'and': 264,
#  'no': 4869,
#  'word': 8240,
#  'back': 533,
#  'id': 3398,
#  'like': 4046,
#  'some': 6675,
#  'fun': 2707,
#  'you': 8451,
#  'up': 7759,
#  'for': 2585,
#  'it': 3594,
#  'still': 6911,
#  'tb': 7199,
#  'xxx': 8383,
#  'std': 6886,
#  'chgs': 1219,
#  'send': 6336,
#  'rcv': 5849,
#  'even': 2266,
#  'my': 4720,
#  'brother': 911,
#  'is': 3582,
#  'not': 4914,
#  'speak': 6755,
#  'with': 8190,
#  'me': 4383,
#  'they': 7343,
#  'treat': 7581,
#  'aids': 165,
#  'patent': 5278,
#  'as': 408,
#  'per': 5322,
#  'your': 8468,
#  'request': 6004,
#  'melle': 4419,
#  'oru': 5138,
#  'minnaminunginte': 4502,
#  'nurungu': 4966,
#  'vettam': 7871,
#  'has': 3079,
#  'set': 6366,
#  'callertune': 1014,
#  'all': 204,
#  'callers': 1013,
#  'press': 5620,
#  'copy': 1496,
#  'friends': 2667,
#  'winner': 8171,
#  'valued': 7840,
#  'network': 4809,
#  'customer': 1626,
#  'have': 3091,
#  'selected': 6322,
#  'receivea': 5894,
#  'prize': 5654,
#  'reward': 6063,
#  'claim': 1280,
#  'call': 1005,
#  'code': 1341,
#  'kl': 3854,
#  'valid': 7836,
#  'hours': 3298,
#  'had': 3019,
#  'mobile': 4562,
#  'months': 4607,
#  'or': 5115,
#  'more': 4614,
#  'entitled': 2216,
#  'update': 7763,
#  'the': 7309,
#  'latest': 3946,
#  'colour': 1364,
#  'mobiles': 4563,
#  'camera': 1040,
#  'co': 1330,
#  'on': 5061,
#  'im': 3429,
#  'gonna': 2876,
#  'be': 624,
#  'home': 3246,
#  'soon': 6705,
#  'want': 7982,
#  'talk': 7165,
#  'about': 18,
#  'this': 7361,
#  'stuff': 6986,
#  'anymore': 305,
#  'tonight': 7504,
#  'ive': 3623,
#  'cried': 1575,
#  'enough': 2207,
#  'today': 7464,
#  'six': 6556,
#  'chances': 1157,
#  'cash': 1100,
#  'from': 2685,
#  'pounds': 5555,
#  'csh': 1593,
#  'cost': 1509,
#  'pday': 5303,
#  'days': 1703,
#  'tsandcs': 7616,
#  'reply': 5996,
#  'hl': 3213,
#  'info': 3492,
#  'urgent': 7785,
#  'won': 8224,
#  'week': 8054,
#  'membership': 4425,
#  'our': 5150,
#  'jackpot': 3632,
#  'tc': 7201,
#  'wwwdbuknet': 8329,
#  'lccltd': 3965,
#  'pobox': 5473,
#  'ldnwarw': 3967,
#  'searching': 6289,
#  'right': 6075,
#  'words': 8243,
#  'thank': 7291,
#  'breather': 880,
#  'promise': 5693,
#  'wont': 8231,
#  'take': 7156,
#  'help': 3143,
#  'granted': 2931,
#  'will': 8156,
#  'fulfil': 2703,
#  'wonderful': 8228,
#  'blessing': 761,
#  'at': 443,
#  'times': 7422,
#  'date': 1686,
#  'sunday': 7053,
#  'xxxmobilemovieclub': 8384,
#  'use': 7800,
#  'credit': 1565,
#  'click': 1302,
#  'wap': 7987,
#  'link': 4069,
#  'next': 4827,
#  'message': 4450,
#  'httpwap': 3327,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 8385,
#  'oh': 5029,
#  'kim': 3821,
#  'watching': 8008,
#  'eh': 2141,
#  'remember': 5963,
#  'how': 3305,
#  'spell': 6771,
#  'his': 3201,
#  'name': 4740,
#  'yes': 8424,
#  'did': 1853,
#  'naughty': 4764,
#  'make': 4289,
#  'wet': 8097,
#  'fine': 2489,
#  'if': 3411,
#  'thats': 7306,
#  'way': 8020,
#  'feel': 2432,
#  'gota': 2904,
#  'england': 2198,
#  'macedonia': 4252,
#  'miss': 4522,
#  'goalsteam': 2850,
#  'news': 4822,
#  'ur': 7782,
#  'national': 4757,
#  'team': 7217,
#  'eg': 2133,
#  'trywales': 7614,
#  'scotland': 6268,
#  'poboxoxwwq': 5478,
#  'that': 7299,
#  'seriously': 6359,
#  'going': 2864,
#  'try': 7611,
#  'ha': 3015,
#  'pay': 5291,
#  'first': 2509,
#  'when': 8109,
#  'da': 1642,
#  'stock': 6915,
#  'comin': 1380,
#  'aft': 126,
#  'finish': 2495,
#  'lunch': 4227,
#  'str': 6944,
#  'down': 2000,
#  'lor': 4153,
#  'ard': 366,
#  'smth': 6642,
#  'ffffffffff': 2450,
#  'alright': 222,
#  'can': 1045,
#  'meet': 4404,
#  'sooner': 6707,
#  'just': 3742,
#  'forced': 2587,
#  'myself': 4725,
#  'eat': 2105,
#  'slice': 6592,
#  'really': 5874,
#  'hungry': 3355,
#  'tho': 7371,
#  'sucks': 7025,
#  'mark': 4326,
#  'getting': 2803,
#  'worried': 8260,
#  'knows': 3865,
#  'sick': 6499,
#  'turn': 7637,
#  'pizza': 5415,
#  'lol': 4130,
#  'always': 232,
#  'convincing': 1482,
#  'catch': 1112,
#  'bus': 964,
#  'are': 367,
#  'frying': 2691,
#  'an': 259,
#  'egg': 2136,
#  'tea': 7211,
#  'eating': 2108,
#  'moms': 4586,
#  'left': 3988,
#  'over': 5172,
#  'dinner': 1885,
#  'do': 1936,
#  'love': 4178,
#  'amp': 249,
#  'were': 8085,
#  'packing': 5201,
#  'car': 1067,
#  'ill': 3425,
#  'let': 4013,
#  'know': 3861,
#  'theres': 7334,
#  'room': 6119,
#  'ahhh': 156,
#  'work': 8246,
#  'vaguely': 7831,
#  'what': 8102,
#  'does': 1949,
#  'wait': 7953,
#  'clear': 1296,
#  'sure': 7081,
#  'being': 668,
#  'sarcastic': 6220,
#  'why': 8137,
#  'doesnt': 1951,
#  'live': 4092,
#  'us': 7796,
#  'yeah': 8411,
#  'was': 7997,
#  'apologetic': 326,
#  'fallen': 2382,
#  'out': 5153,
#  'she': 6414,
#  'actin': 64,
#  'spoilt': 6799,
#  'child': 1235,
#  'caught': 1116,
#  'till': 7417,
#  'but': 971,
#  'we': 8027,
#  'doing': 1962,
#  'too': 7510,
#  'badly': 539,
#  'cheers': 1201,
#  'tell': 7236,
#  'anything': 311,
#  'fear': 2424,
#  'of': 5002,
#  'fainting': 2372,
#  'housework': 3303,
#  'quick': 5785,
#  'cuppa': 1616,
#  'thanks': 7292,
#  'subscription': 7013,
#  'ringtone': 6084,
#  'uk': 7686,
#  'charged': 1169,
#  'month': 4603,
#  'please': 5444,
#  'confirm': 1437,
#  'by': 986,
#  'replying': 5998,
#  'yup': 8494,
#  'look': 4141,
#  'timings': 7429,
#  'msg': 4660,
#  'again': 134,
#  'xuhui': 8379,
#  'learn': 3977,
#  'nd': 4770,
#  'her': 3154,
#  'lesson': 4011,
#  'am': 234,
#  'oops': 5089,
#  'roommates': 6122,
#  'done': 1976,
#  'see': 6306,
#  'letter': 4015,
#  'decide': 1741,
#  'hello': 3136,
#  'hows': 3311,
#  'saturday': 6234,
#  'texting': 7279,
#  'youd': 8455,
#  'decided': 1742,
#  'tomo': 7489,
#  'trying': 7613,
#  'invite': 3557,
#  'pls': 5452,
#  'ahead': 154,
#  'watts': 8017,
#  'wanted': 7984,
#  'weekend': 8056,
#  'abiola': 14,
#  'forget': 2593,
#  'need': 4783,
#  'crave': 1554,
#  'most': 4628,
#  'sweet': 7111,
#  'arabian': 363,
#  'steed': 6893,
#  'mmmmmm': 4552,
#  'yummy': 8489,
#  'rodger': 6108,
#  'burns': 961,
#  'tried': 7590,
#  're': 5853,
#  'sms': 6637,
#  'nokia': 4885,
#  'camcorder': 1038,
#  'delivery': 1780,
#  'tomorrow': 7492,
#  'who': 8130,
#  'seeing': 6308,
#  'hope': 3270,
#  'man': 4299,
#  'well': 8073,
#  'endowed': 2188,
#  'ltgt': 4212,
#  'inches': 3460,
#  'callsmessagesmissed': 1030,
#  'calls': 1029,
#  'didnt': 1855,
#  'get': 2794,
#  'hep': 3153,
#  'immunisation': 3441,
#  'nigeria': 4840,
#  'fair': 2373,
#  'hopefully': 3274,
#  'tyler': 7666,
#  'cant': 1058,
#  'could': 1521,
#  'maybe': 4375,
#  'ask': 419,
#  'bit': 735,
#  'stubborn': 6975,
#  'hospital': 3286,
#  'kept': 3792,
#  'telling': 7237,
#  'weak': 8028,
#  'sucker': 7023,
#  'hospitals': 3287,
#  'suckers': 7024,
#  'thinked': 7354,
#  'time': 7419,
#  'saw': 6241,
#  'class': 1288,
#  'gram': 2923,
#  'usually': 7817,
#  'runs': 6165,
#  'half': 3033,
#  'eighth': 2144,
#  'smarter': 6615,
#  'gets': 2799,
#  'almost': 216,
#  'whole': 8131,
#  'second': 6293,
#  'fyi': 2723,
#  'ride': 6074,
#  'morning': 4618,
#  'hes': 3169,
#  'crashing': 1553,
#  'place': 5417,
#  'wow': 8279,
#  'never': 4813,
#  'realized': 5872,
#  'embarassed': 2169,
#  'accomodations': 44,
#  'thought': 7377,
#  'liked': 4047,
#  'since': 6526,
#  'best': 688,
#  'seemed': 6312,
#  'happy': 3068,
#  'cave': 1120,
#  'sorry': 6717,
#  'give': 2827,
#  'offered': 5009,
#  'embarassing': 2170,
#  'ac': 30,
#  'sptv': 6822,
#  'new': 4817,
#  'jersey': 3675,
#  'devils': 1833,
#  'detroit': 1827,
#  'red': 5917,
#  'wings': 8169,
#  'play': 5433,
#  'ice': 3393,
#  'hockey': 3230,
#  'correct': 1501,
#  'incorrect': 3471,
#  'end': 2184,
#  'mallika': 4298,
#  'sherawat': 6421,
#  'yesterday': 8434,
#  'find': 2486,
#  'lturlgt': 4216,
#  'congrats': 1444,
#  'year': 8413,
#  'special': 6757,
#  'cinema': 1275,
#  'pass': 5266,
#  'yours': 8472,
#  'suprman': 7079,
#  'matrix': 4361,
#  'starwars': 6872,
#  'etc': 2252,
#  'bxipwe': 985,
#  'pm': 5461,
#  'later': 3944,
#  'meeting': 4407,
#  'where': 8115,
#  'reached': 5856,
#  'yesgauti': 8427,
#  'sehwag': 6319,
#  'odi': 5001,
#  'series': 6357,
#  'pick': 5385,
#  'burger': 956,
#  'yourself': 8473,
#  'move': 4642,
#  'pain': 5208,
#  'killing': 3818,
#  'good': 2878,
#  'joke': 3703,
#  'girls': 2824,
#  'situation': 6552,
#  'seekers': 6309,
#  'part': 5253,
#  'checking': 1195,
#  'iq': 3571,
#  'took': 7511,
#  'forever': 2590,
#  'come': 1372,
#  'double': 1992,
#  'check': 1191,
#  'hair': 3028,
#  'dresser': 2027,
#  'said': 6187,
#  'wun': 8315,
#  'cut': 1630,
#  'short': 6461,
#  'nice': 4833,
#  'pleased': 5445,
#  'advise': 108,
#  'following': 2568,
#  'recent': 5897,
#  'review': 6061,
#  'mob': 4560,
#  'awarded': 508,
#  'bonus': 804,
#  'song': 6699,
#  'dedicated': 1752,
#  'day': 1698,
#  'which': 8123,
#  'dedicate': 1751,
#  'valuable': 7838,
#  'frnds': 2676,
#  'rply': 6139,
#  'complimentary': 1409,
#  'trip': 7591,
#  'eurodisinc': 2258,
#  'trav': 7573,
#  'acoentry': 59,
#  'dis': 1898,
#  'morefrmmob': 4615,
#  'shracomorsglsuplt': 6485,
#  'ls': 4202,
#  'aj': 176,
#  'hear': 3112,
#  'divorce': 1927,
#  'barbie': 572,
#  'comes': 1376,
#  'kens': 3790,
#  'plane': 5424,
#  'wah': 7946,
#  'lucky': 4220,
#  'save': 6237,
#  'money': 4591,
#  'hee': 3128,
#  'finished': 2497,
#  'hi': 3179,
#  'babe': 522,
#  'wanna': 7980,
#  'something': 6685,
#  'xx': 8380,
#  'kkwhere': 3851,
#  'youhow': 8458,
#  'performed': 5329,
#  'waiting': 7957,
#  'machan': 4254,
#  'once': 5064,
#  'cool': 1488,
#  'gentleman': 2785,
#  'dignity': 1875,
#  'respect': 6025,
#  'peoples': 5321,
#  'very': 7870,
#  'much': 4679,
#  'shy': 6494,
#  'pa': 5196,
#  'operate': 5096,
#  'after': 127,
#  'same': 6204,
#  'looking': 4145,
#  'job': 3690,
#  'tas': 7183,
#  'earn': 2093,
#  'ah': 152,
#  'stop': 6925,
#  'urgnt': 7789,
#  'real': 5866,
#  'yo': 8445,
#  'tickets': 7408,
#  'one': 5066,
#  'jacket': 3631,
#  'used': 7801,
#  'multis': 4690,
#  'started': 6865,
#  'requests': 6005,
#  'came': 1039,
#  'bed': 642,
#  'coins': 1348,
#  'factory': 2363,
#  'gotta': 2909,
#  'nitros': 4864,
#  'ela': 2149,
#  'kanoil': 3766,
#  'download': 2001,
#  'wen': 8079,
#  'stand': 6853,
#  'close': 1309,
#  'youll': 8462,
#  'another': 288,
#  'night': 4842,
#  'spent': 6776,
#  'late': 3939,
#  'afternoon': 129,
#  'casualty': 1110,
#  'means': 4390,
#  'havent': 3093,
#  'any': 301,
#  'stuffmoro': 6990,
#  'includes': 3464,
#  'sheets': 6416,
#  'smile': 6624,
#  'pleasure': 5447,
#  'trouble': 7597,
#  'pours': 5557,
#  'rain': 5809,
#  'sum': 7045,
#  'hurts': 3369,
#  'becoz': 640,
#  'someone': 6678,
#  'loves': 4188,
#  'smiling': 6628,
#  'service': 6362,
#  'representative': 6002,
#  'between': 697,
#  'ampm': 251,
#  'guaranteed': 2983,
#  'planning': 5429,
#  'buy': 976,
#  'lido': 4028,
#  'show': 6476,
#  'collected': 1357,
#  'simply': 6523,
#  'password': 5274,
#  'mix': 4542,
#  'verify': 7866,
#  'usher': 7808,
#  'britney': 901,
#  'fml': 2558,
#  'telugu': 7242,
#  'moviewat': 4647,
#  'abt': 25,
#  'loads': 4107,
#  'loans': 4109,
#  'wk': 8201,
#  'hols': 3244,
#  'run': 6162,
#  'forgot': 2598,
#  'hairdressers': 3030,
#  'appointment': 342,
#  'four': 2616,
#  'shower': 6478,
#  'beforehand': 656,
#  'cause': 1117,
#  'prob': 5660,
#  'ham': 3039,
#  'nothing': 4919,
#  'else': 2163,
#  'okay': 5037,
#  'price': 5633,
#  'long': 4137,
#  'legal': 3991,
#  'them': 7317,
#  'ave': 495,
#  'ams': 254,
#  'gone': 2873,
#  'driving': 2036,
#  'test': 7266,
#  'yet': 8435,
#  'youre': 8469,
#  'mean': 4386,
#  'guess': 2991,
#  'gave': 2756,
#  'boston': 826,
#  'men': 4430,
#  'changed': 1159,
#  'search': 6288,
#  'location': 4112,
#  'nyc': 4976,
#  'cuz': 1637,
#  'signin': 6511,
#  'page': 5204,
#  'says': 6246,
#  'umma': 7695,
#  'life': 4031,
#  'vava': 7852,
#  'lot': 4163,
#  'dear': 1723,
#  'wishes': 8184,
#  'birthday': 733,
#  'making': 4293,
#  'truly': 7605,
#  'memorable': 4427,
#  'aight': 167,
#  'hit': 3204,
#  'would': 8275,
#  'ip': 3565,
#  'address': 83,
#  'considering': 1455,
#  'computer': 1416,
#  'isnt': 3591,
#  'minecraft': 4497,
#  'server': 6361,
#  'grumpy': 2975,
#  'old': 5054,
#  'people': 5320,
#  'mom': 4583,
#  'better': 695,
#  'lying': 4243,
#  'jokes': 3705,
#  'worry': 8263,
#  'busy': 969,
#  'plural': 5457,
#  'noun': 4928,
#  'research': 6011,
#  'dinnermsg': 1886,
#  'cos': 1507,
#  'things': 7352,
#  'scared': 6253,
#  'mah': 4276,
#  'loud': 4173,
#  'gent': 2783,
#  'contact': 1460,
#  'last': 3936,
#  'weekends': 8057,
#  'draw': 2015,
#  'shows': 6484,
#  'hrs': 3318,
#  'ppm': 5565,
#  'wa': 7942,
#  'openin': 5093,
#  'sentence': 6349,
#  'formal': 2601,
#  'anyway': 315,
#  'juz': 3746,
#  'tt': 7622,
#  'eatin': 2107,
#  'puttin': 5761,
#  'weighthaha': 8064,
#  'anythin': 310,
#  'happened': 3060,
#  'entered': 2209,
#  'cabin': 991,
#  'bday': 623,
#  'boss': 825,
#  'felt': 2441,
#  'askd': 420,
#  'invited': 3558,
#  'apartment': 320,
#  'went': 8082,
#  'specially': 6762,
#  'holiday': 3240,
#  'flights': 2535,
#  'inc': 3458,
#  'operator': 5097,
#  'pmin': 5463,
#  'goodo': 2892,
#  'must': 4710,
#  'friday': 2660,
#  'eggpotato': 2137,
#  'ratio': 5839,
#  'tortilla': 7530,
#  'needed': 4785,
#  'hmmmy': 3226,
#  'uncle': 7703,
#  'informed': 3496,
#  'paying': 5296,
#  'school': 6259,
#  'directly': 1892,
#  'food': 2575,
#  'private': 5651,
#  'account': 48,
#  'statement': 6875,
#  'unredeemed': 7747,
#  'points': 5491,
#  'identifier': 3405,
#  'expires': 2334,
#  'caller': 1012,
#  'landline': 3916,
#  'boxwrc': 848,
#  'applespairsall': 337,
#  'malarky': 4295,
#  'todays': 7470,
#  'voda': 7920,
#  'numbers': 4962,
#  'ending': 2186,
#  'award': 507,
#  'match': 4349,
#  'quoting': 5797,
#  'standard': 6854,
#  'rates': 5836,
#  'app': 330,
#  'sao': 6214,
#  'mu': 4678,
#  'predict': 5595,
#  'll': 4100,
#  'buying': 979,
#  'knowyetunde': 3868,
#  'hasnt': 3081,
#  'sent': 6347,
#  'bother': 829,
#  'sending': 6339,
#  'involve': 3562,
#  'shouldnt': 6471,
#  'imposed': 3447,
#  'apologise': 327,
#  'girl': 2820,
#  'del': 1770,
#  'bak': 548,
#  'lucyxx': 4224,
#  'kkhow': 3845,
#  'tmorrowpls': 7451,
#  'accomodate': 43,
#  'answer': 291,
#  'question': 5781,
#  'sunshine': 7060,
#  'quiz': 5792,
#  'top': 7520,
#  'sony': 6702,
#  'dvd': 2080,
#  'player': 5435,
#  'country': 1527,
#  'algarve': 196,
#  'ansr': 290,
#  'sptyrone': 6823,
#  'laid': 3907,
#  'dogging': 1956,
#  'locations': 4113,
#  'direct': 1891,
#  'join': 3698,
#  'uks': 7689,
#  'largest': 3933,
#  'bt': 927,
#  'txting': 7660,
#  'gravel': 2936,
#  'nt': 4950,
#  'eca': 2110,
#  'pmsgp': 5466,
#  'haf': 3022,
#  'msn': 4671,
#  'yijuehotmailcom': 8442,
#  'him': 3193,
#  'rooms': 6123,
#  'befor': 654,
#  'activities': 70,
#  'msgs': 4664,
#  'chat': 1181,
#  'svc': 7097,
#  'hardcore': 3070,
#  'services': 6363,
#  'age': 139,
#  'yr': 8484,
#  'lazy': 3963,
#  'type': 7668,
#  'lect': 3985,
#  'pouch': 5552,
#  'sir': 6538,
#  'mail': 4280,
#  'swt': 7126,
#  'nver': 4971,
#  'tired': 7432,
#  'little': 4091,
#  'lovable': 4177,
#  'persons': 5347,
#  'cozsomtimes': 1541,
#  'those': 7372,
#  'occupy': 4993,
#  'biggest': 714,
#  'their': 7314,
#  'hearts': 3120,
#  'gud': 2985,
#  'ni': 4831,
#  'open': 5090,
#  'ya': 8395,
#  'dot': 1991,
#  'whats': 8104,
#  'staff': 6844,
#  'taking': 7162,
#  'replied': 5994,
#  'randy': 5829,
#  'sexy': 6379,
#  'female': 2442,
#  'local': 4111,
#  'luv': 4233,
#  'netcollex': 4805,
#  'ltd': 4207,
#  'ummmawill': 7696,
#  'inour': 3513,
#  'begin': 661,
#  'qatar': 5768,
#  'pray': 5587,
#  'hard': 3069,
#  'ki': 3806,
#  'deleted': 1774,
#  'sindu': 6528,
#  'birla': 729,
#  'soft': 6665,
#  'wine': 8167,
#  'flowing': 2549,
#  'nevering': 4814,
#  'thk': 7363,
#  'plaza': 5442,
#  'typical': 7671,
#  'everywhere': 2284,
#  'dirt': 1895,
#  'floor': 2543,
#  'windows': 8164,
#  'shirt': 6435,
#  'sometimes': 6689,
#  'mouth': 4641,
#  'dream': 2019,
#  'without': 8194,
#  'chores': 1261,
#  'joy': 3720,
#  'lots': 4166,
#  'tv': 7642,
#  'exist': 2317,
#  'hail': 3027,
#  'mist': 4533,
#  'become': 638,
#  'aaooooright': 3,
#  'leaving': 3984,
#  'house': 3299,
#  'interview': 3543,
#  'boy': 849,
#  'meare': 4393,
#  'missing': 4526,
#  'annoncement': 281,
#  'years': 8414,
#  'arrange': 394,
#  'keep': 3784,
#  'safe': 6182,
#  'because': 636,
#  'envy': 2223,
#  'everyone': 2278,
#  'sees': 6316,
#  'parentsi': 5244,
#  'hand': 3042,
#  'excited': 2305,
#  'each': 2086,
#  'spend': 6774,
#  'bootydelious': 817,
#  'inviting': 3559,
#  'friend': 2665,
#  'wwwsmsacubootydelious': 8349,
#  'frnd': 2675,
#  'bangbabes': 562,
#  'order': 5122,
#  'should': 6469,
#  'content': 1464,
#  'goto': 2908,
#  'bangb': 561,
#  'internetservice': 3542,
#  'menu': 4438,
#  'cultures': 1610,
#  'module': 4576,
#  'avoid': 501,
#  'missunderstding': 4531,
#  'wit': 8189,
#  'beloved': 678,
#  'ones': 5068,
#  'escape': 2242,
#  'fancy': 2394,
#  'bridge': 885,
#  'needs': 4789,
#  'lager': 3906,
#  'completely': 1405,
#  'formclark': 2605,
#  'also': 226,
#  ...}

# %%
vec = CountVectorizer(stop_words='english')
vec.fit(X)
vocabulary = vec.vocabulary_

# %% [markdown]
# Now We'll convert convert X,y to numpy array

# %%
X = df1['v2'].to_numpy()
Y = df1['v1'].to_numpy()
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(Y)
print(X)
print(y)
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat'
#  'ok lar joking wif u oni'
#  'free entry in  a wkly comp to win fa cup final tkts st may  text fa to  to receive entry questionstd txt ratetcs apply overs'
#  ... 'pity  was in mood for that soany other suggestions'
#  'the guy did some bitching but i acted like id be interested in buying something else next week and he gave it to us for free'
#  'rofl its true to its name']
# [0 0 1 ... 0 0 0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
vector = CountVectorizer()
X_train_count = vector.fit_transform(X_train)
X_test_count = vector.transform(X_test)
print(len(vector.vocabulary_))
# Out:
# 8034

# %% [markdown]
# We'll use NaiveBayse multinomial method

# %%
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_count, y_train)
y_pred = nb_classifier.predict(X_test_count)

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9874551971326165

# %% [markdown]
# 0.1 test size gives the highest accuracy
